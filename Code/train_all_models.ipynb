# %% [markdown]
# # Training Notebook für alle drei Modelle
#
# Dieses Notebook installiert die Requirements und startet die drei Trainingsskripte einzeln.
# Einfach die Daten aus dem Git Repository ziehen (https://github.com/JRohm1999/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit.git), importieren und die Zellen im Notebook nacheinander ausführen.

# %% [markdown]
# # Import der Files aus dem Git Repository

# %%
# !git clone https://github.com/JRohm1999/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit.git

# %% [markdown]
# Die Struktur aus dem Git Repositor ist bereits korrekt. Nun kann der Pfad im Workspace geöffnet werden und die Bibliotheken per requirements.txt importiert werden.

# %%
# Setup: in den Code-Ordner wechseln und Requirements installieren
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit/Code
# !python -V
# !pip install -r requirements.txt

# %%
# Setup: in den Code-Ordner wechseln und Requirements installieren
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit/
# Out:
# /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit

# %% [markdown]
# # Training der Modelle
# 1. LSTM Many-to-One
# 2. LSTM Seq-to-Seq
# 3. TFT
#
# Das Anpassen der Parameter wird per Anpassung im File selbst vorgenommen.

# %%
# Training 1: LSTM Many-to-One
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit
# !python Code/train_lstm_many_to_one.py

# %%
# Training 2: LSTM Seq-to-Seq
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit
# !python Code/train_lstm_seq_to_seq.py

# %%
# Training 3: TFT
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit
# !python Code/train_TFT.py

# %%
# Training 4: PatchTST
# %cd /workspace/LSTM-vs-Transformer-Zeitreihenprognose-Masterarbeit
# !python Code/train_PatchTST.py

# %% [markdown]
# Automatischer Stop der Instanz nachdem alle Modelle Traininert sind.

# %%
# !bash -c 'sleep 10; runpodctl stop pod (Hier_Pod_ID_Eintragen)'
